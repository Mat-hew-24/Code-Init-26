# %% [markdown]
# # Grid-X Test Notebook
# This is a sample Jupyter notebook for testing Grid-X distributed execution.

# %%
# Basic Python computation
import math
import time

print("hi bro")
print("="*10)

print("🌟 Grid-X Jupyter Notebook Execution")
print(f"Execution time: {time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Pi = {math.pi}")
print(f"e = {math.e}")

# %%
# Data analysis example
import pandas as pd
import numpy as np

# Create sample data
data = {
    'x': np.random.randn(100),
    'y': np.random.randn(100),
    'z': np.random.randint(1, 10, 100)
}

df = pd.DataFrame(data)
print("Sample DataFrame created:")
print(df.head())
print(f"\nDataFrame shape: {df.shape}")
print(f"Mean values:\n{df.mean()}")

# %%
# Mathematical computation
result = sum(i**2 for i in range(1000))
print(f"Sum of squares from 1 to 1000: {result}")

# Fibonacci sequence
def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)

fib_result = [fibonacci(i) for i in range(10)]
print(f"First 10 Fibonacci numbers: {fib_result}")

# %% [markdown]
# ## Computation Complete
# This notebook demonstrates:
# - Basic Python operations
# - Data manipulation with pandas
# - Mathematical computations
# - Grid-X distributed execution
